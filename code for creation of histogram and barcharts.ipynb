# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


# new line graph with cleaned photos

# %%
data = {'Species': ['Bear', 'Cat', 'Dog', 'Elephant', 'Goat', 'Horse', 'Lion', 'Tiger', 'Wolf'], 'Average Width of Images': [1699,1699,2434,1412,1370,1300,1329,1205,1332]}


yippee = pd.DataFrame(data)


print(yippee)
# Out:
#     Species  Average Width of Images
# 0      Bear                     1699
# 1       Cat                     1699
# 2       Dog                     2434
# 3  Elephant                     1412
# 4      Goat                     1370
# 5     Horse                     1300
# 6      Lion                     1329
# 7     Tiger                     1205
# 8      Wolf                     1332

# %%
sns.barplot(data, x="Species", y="Average Width of Images")
plt.show()

# %%
sns.histplot(data=data, x="Average Width of Images", binwidth = 100, bins= 9, hue="Species", multiple="stack", element="step",kde="True")
# Out:
# <Axes: xlabel='Average Width of Images', ylabel='Count'>
