# %%
from PIL import Image
image = Image.open('mammals/bear/00000000.jpg')

# summarize some details about the image
print(image.format)
print(image.size)
print(image.mode)
# Out:
# JPEG
# (1200, 805)
# RGB

# %%
import os
import numpy as np
import cv2
from PIL import Image

# %%
tigers = list()
path = os.path.dirname("mammals/tigers/")
for item in os.listdir(path):
 if '.jpg' in item:  
    img = Image.open(os.path.join(path, item))
    numpydata = np.asarray(img)
    if image is not None:
        tigers.append(image)

# %%
def height():
    heights = []
    for fp in os.listdir(path):
       print(fp) 
       #read image
       img= cv2.imread('mammals/tigers/'+fp, cv2.IMREAD_UNCHANGED)

       # get dimensions of image
       dimensions = img.shape
    
       # height, width, number of channels in image
       height = img.shape[0]
       heights.append(height)
       print('Image Height: ',height)
    
    return heights 

average_height = np.mean(height(), axis = 0)
print(average_height)
# Out:
# 00000001.jpg
# Image Height:  720
# 00000002.jpg
# Image Height:  500
# 00000003.jpg
# Image Height:  900
# 00000004.jpg
# Image Height:  2592
# 00000005.jpg
# Image Height:  750
# 00000006.jpg
# Image Height:  568
# 00000007.jpg
# Image Height:  1200
# 00000008.jpg
# Image Height:  853
# 00000009.jpg
# Image Height:  785
# 00000010.jpg
# Image Height:  1200
# 00000011.jpg
# Image Height:  1080
# 00000012.jpg
# Image Height:  1880
# 00000013.jpg
# Image Height:  520
# 00000014.jpg
# Image Height:  1200
# 00000015.jpg
# Image Height:  1067
# 00000017.jpg
# Image Height:  1440
# 00000018.jpg
# Image Height:  433
# 00000020.jpg
# Image Height:  736
# 00000021.jpg
# Image Height:  1432
# 00000022.jpg
# Image Height:  1600
# 00000023.jpg
# Image Height:  700
# 00000024.jpg
# Image Height:  1094
# 00000027.jpg
# Image Height:  351
# 00000028.jpg
# Image Height:  659
# 00000029.jpg
# Image Height:  1204
# 00000030.jpg
# Image Height:  418
# 00000032.jpg
# Image Height:  1150
# 00000036.jpg
# ...

# %%
def width():
    widths = []
    for fp in os.listdir(path):
       print(fp) 
       #read image
       img= cv2.imread('mammals/tigers/'+fp, cv2.IMREAD_UNCHANGED)

       # get dimensions of image
       dimensions = img.shape
    
       # height, width, number of channels in image
       width = img.shape[1]
       widths.append(width)
       print('Image Width: ',width)

    return widths

average_width = np.mean(width(), axis = 0)
print(average_width)
# Out:
# 00000001.jpg
# Image Width:  1280
# 00000002.jpg
# Image Width:  800
# 00000003.jpg
# Image Width:  600
# 00000004.jpg
# Image Width:  2456
# 00000005.jpg
# Image Width:  1000
# 00000006.jpg
# Image Width:  830
# 00000007.jpg
# Image Width:  1600
# 00000008.jpg
# Image Width:  1280
# 00000009.jpg
# Image Width:  640
# 00000010.jpg
# Image Width:  1920
# 00000011.jpg
# Image Width:  1920
# 00000012.jpg
# Image Width:  2480
# 00000013.jpg
# Image Width:  677
# 00000014.jpg
# Image Width:  1920
# 00000015.jpg
# Image Width:  1600
# 00000017.jpg
# Image Width:  2560
# 00000018.jpg
# Image Width:  650
# 00000020.jpg
# Image Width:  736
# 00000021.jpg
# Image Width:  2788
# 00000022.jpg
# Image Width:  2159
# 00000023.jpg
# Image Width:  565
# 00000024.jpg
# Image Width:  1448
# 00000027.jpg
# Image Width:  640
# 00000028.jpg
# Image Width:  908
# 00000029.jpg
# Image Width:  1600
# 00000030.jpg
# Image Width:  600
# 00000032.jpg
# Image Width:  1920
# 00000036.jpg
# Image Width:  1600
# ...
